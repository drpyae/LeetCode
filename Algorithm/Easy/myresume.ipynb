# %% [markdown]
# **Pyae Phyo Aung**
# Email: drpyaephyoaung@outlook.com | Phone: +959762111150 | LinkedIn: linkedin.com/in/ppaung
#
# ---
#
# ### **Professional Summary**
# Data Scientist with a robust background in public health, data management, and program management. Proficient in Python, R, SQL, and data visualization tools like Tableau and Power BI. Proven experience in designing and deploying data systems, conducting data analysis, and improving data quality for strategic decision-making. Adept at leading data-driven projects, mentoring teams, and applying analytical skills to optimize health programs and operations. Passionate about leveraging data science to drive impactful outcomes in diverse and dynamic environments.
#
# ---
#
# ### **Professional Experience**
#
# **Data Science Instructor**
# *Ethan Tech*
# *Jan 2023 - Present | Taunggyi District, Shan State, Myanmar (Virtual)*
# - Developed and delivered a comprehensive data science curriculum in Python and R, boosting student engagement by 20%.
# - Designed training materials and exercises, increasing student participation by 15% and improving grades by 10%.
# - Mentored students on technical skills and career readiness, resulting in 80% securing internships.
# - Collaborated with peers to enhance course content, leading to a 25% increase in enrollment.
#
# **National Consultant**
# *World Health Organization*
# *Aug 2020 - Feb 2021 | Naypyitaw, Myanmar (On-site)*
# - Developed a Health Management Information System for vaccine deployment, enhancing data accuracy by 30%.
# - Integrated ATM/HMIS with DHIS2, improving data retrieval speed by 25% and reducing errors by 15%.
# - Deployed a Data Quality Assessment Module using PostgreSQL and IBM Db2, raising data quality metrics by 20%.
# - Trained over 1,000 healthcare professionals in eHealth practices, standardizing data management procedures.
#
# **Program Officer - Data Management**
# *Clinton Health Access Initiative*
# *Dec 2018 - Mar 2020 | Yangon, Myanmar (On-site)*
# - Designed and implemented data collection tools and reporting dashboards, improving data entry accuracy by 25%.
# - Led the development of a national electronic patient management system, enhancing patient data accessibility.
# - Provided data management expertise for MDR-TB and HIV programs, reducing data processing time by 20%.
# - Produced analytical reports to inform policy decisions, improving program outcomes by 15%.
#
# **ART Program Officer**
# *Pyi Gyi Khin*
# *Oct 2016 - Dec 2018 | National AIDS Program, Taunggyi (On-Site)*
# - Managed data reporting and analytics for the ART program, achieving a 10% improvement in monitoring accuracy.
# - Developed workflows and tools for monthly data reporting, reducing stockouts and enhancing patient outcomes by 25%.
# - Led capacity-building initiatives for staff and volunteers, increasing patient reach by 30%.
#
# **Medical Doctor**
# *MERCY Malaysia*
# *Sep 2015 - Oct 2016 | Sittwe, Myanmar (On-Site)*
# - Provided direct medical care to over 200 patients, improving health outcomes by 30%.
# - Streamlined healthcare delivery processes in collaboration with local authorities, reducing patient wait times by 20%.
#
# ---
#
# ### **Education**
# - **M.B; B.S** | University of Medicine, Magway | 2007 – 2014
# - **Google Analytics Professional Certificate**
# - **IBM Data Science Professional Certificate**
#
# ---
#
# ### **Skills**
# - **Data Science & Analysis:** Python, R, SQL, Tableau, Power BI
# - **Data Management & Integration:** PostgreSQL, IBM Db2, DHIS2, Commcare, Kobo Toolbox
# - **Program Management:** Project coordination, data system implementation, monitoring & evaluation
# - **Training & Capacity Building:** Curriculum development, data literacy training, mentoring
# - **Leadership & Strategy:** Leading data initiatives, cross-functional team collaboration, decision-making support
#
# ---
#
# ### **Relevant Experience Highlights**
# - **Data System Development:** Led design and implementation of data management systems for health programs.
# - **Data Analysis & Reporting:** Developed dashboards and tools to enhance data collection, analysis, and reporting.
# - **Training & Mentorship:** Conducted training sessions and mentoring programs, boosting staff capabilities in data management.
# - **Data Quality Improvement:** Executed data quality assurance initiatives, ensuring accuracy and supporting adaptive management.
